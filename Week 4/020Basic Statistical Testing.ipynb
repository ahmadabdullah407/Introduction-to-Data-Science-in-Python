# %% [markdown]
# In this lecture we're going to review some of the basics of statistical testing in python. We're going to talk about hypothesis testing, statistical significance, and using scipy to run student's t-tests.

# %% [markdown]
# We use statistics in a lot of different ways in data science.
#
# ## hypothesis testing:
# I want to refresh your knowledge of hypothesis testing, which is a core data analysis activity behind experimentation. The goal of
# hypothesis testing is to determine if, for instance, the two different conditions we have in an experiment
# have resulted in different impacts
#
# Let's import our usual numpy and pandas libraries and let's bring in some new libraries from scipy

# %%
import numpy as np
import pandas as pd
from scipy import stats

# %% [markdown]
# ### scipy:
# Now, scipy is an interesting collection of libraries for data science and you'll use most or perpahs all of
# these libraries. It includes numpy and pandas, but also plotting libraries such as matplotlib, and a
# number of scientific library functions as well

# %% [markdown]
# ### Alternative hypothesis:
# When we do hypothesis testing, we actually have two statements of interest: the first is our actual
# explanation, which we call the alternative hypothesis.
# ### Null hypothesis:
# The second is that the explanation we have is not sufficient, and we call this the null hypothesis.
#
# Our actual testing method is to determine whether the null hypothesis is true or not. If we find that there is a difference between groups, then we can reject the null hypothesis and we accept our alternative.
#
# Let's see an example of this; we're going to use some grade data

# %%
df=pd.read_csv('datasets/grades.csv')
df.head()
# Out:
#                              student_id  assignment1_grade  \
# 0  B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1  98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 2  D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3  FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 4  5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
#
#           assignment1_submission  assignment2_grade  \
# 0  2015-11-02 06:55:34.282000000          83.030552
# 1  2015-11-29 14:57:44.429000000          86.290821
# 2  2016-01-09 05:36:02.389000000          85.512541
# 3  2016-04-30 06:50:39.801000000          68.824532
# 4  2015-12-13 17:06:10.750000000          51.491040
#
#           assignment2_submission  assignment3_grade  \
# 0  2015-11-09 02:22:58.938000000          67.164441
# 1  2015-12-06 17:41:18.449000000          69.772657
# 2  2016-01-09 06:39:44.416000000          68.410033
# 3  2016-04-30 17:20:38.727000000          61.942079
# 4  2015-12-14 12:25:12.056000000          41.932832
#
#           assignment3_submission  assignment4_grade  \
# 0  2015-11-12 08:58:33.998000000          53.011553
# 1  2015-12-10 08:54:55.904000000          55.098125
# 2  2016-01-15 20:22:45.882000000          54.728026
# 3  2016-05-12 07:47:16.326000000          49.553663
# 4  2015-12-29 14:25:22.594000000          36.929549
#
#           assignment4_submission  assignment5_grade  \
# 0  2015-11-16 01:21:24.663000000          47.710398
# 1  2015-12-13 17:32:30.941000000          49.588313
# 2  2016-01-11 12:41:50.749000000          49.255224
# 3  2016-05-07 16:09:20.485000000          49.553663
# 4  2015-12-28 01:29:55.901000000          33.236594
#
#           assignment5_submission  assignment6_grade  \
# 0  2015-11-20 13:24:59.692000000          38.168318
# 1  2015-12-19 23:26:39.285000000          44.629482
# 2  2016-01-11 17:31:12.489000000          44.329701
# 3  2016-05-24 12:51:18.016000000          44.598297
# 4  2015-12-29 14:46:06.628000000          33.236594
#
#           assignment6_submission
# 0  2015-11-22 18:31:15.934000000
# 1  2015-12-21 17:07:24.275000000
# 2  2016-01-17 16:24:42.765000000
# 3  2016-05-26 08:09:12.058000000
# 4  2016-01-05 01:06:59.546000000

# %% [markdown]
# If we take a look at the data frame inside, we see we have six different assignments. Lets look at some
# summary statistics for this DataFrame.

# %%
print('There are {} row and {} columns'.format(df.shape[0],df.shape[1]))
# Out:
# There are 2315 row and 13 columns

# %% [markdown]
# For the purpose of this lecture, let's segment this population into two pieces. Let's say those who finish
# the first assignment by the end of December 2015, we'll call them early finishers, and those who finish it
# sometime after that, we'll call them late finishers.

# %%
early_finishers=df[pd.to_datetime(df['assignment1_submission'])<'2016']
early_finishers.head()
# Out:
#                              student_id  assignment1_grade  \
# 0  B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1  98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 4  5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
# 5  D09000A0-827B-C0FF-3433-BF8FF286E15B          71.647278
# 8  C9D51293-BD58-F113-4167-A7C0BAFCB6E5          66.595568
#
#           assignment1_submission  assignment2_grade  \
# 0  2015-11-02 06:55:34.282000000          83.030552
# 1  2015-11-29 14:57:44.429000000          86.290821
# 4  2015-12-13 17:06:10.750000000          51.491040
# 5  2015-12-28 04:35:32.836000000          64.052550
# 8  2015-12-25 02:29:28.415000000          52.916454
#
#           assignment2_submission  assignment3_grade  \
# 0  2015-11-09 02:22:58.938000000          67.164441
# 1  2015-12-06 17:41:18.449000000          69.772657
# 4  2015-12-14 12:25:12.056000000          41.932832
# 5  2016-01-03 21:05:38.392000000          64.752550
# 8  2015-12-31 01:42:30.046000000          48.344809
#
#           assignment3_submission  assignment4_grade  \
# 0  2015-11-12 08:58:33.998000000          53.011553
# 1  2015-12-10 08:54:55.904000000          55.098125
# 4  2015-12-29 14:25:22.594000000          36.929549
# 5  2016-01-07 08:55:43.692000000          57.467295
# 8  2016-01-05 23:34:02.180000000          47.444809
#
#           assignment4_submission  assignment5_grade  \
# 0  2015-11-16 01:21:24.663000000          47.710398
# 1  2015-12-13 17:32:30.941000000          49.588313
# 4  2015-12-28 01:29:55.901000000          33.236594
# 5  2016-01-11 00:45:28.706000000          57.467295
# 8  2016-01-02 07:48:42.517000000          37.955847
#
#           assignment5_submission  assignment6_grade  \
# 0  2015-11-20 13:24:59.692000000          38.168318
# 1  2015-12-19 23:26:39.285000000          44.629482
# 4  2015-12-29 14:46:06.628000000          33.236594
# 5  2016-01-11 00:54:13.579000000          57.467295
# 8  2016-01-03 21:27:04.266000000          37.955847
#
#           assignment6_submission
# 0  2015-11-22 18:31:15.934000000
# 1  2015-12-21 17:07:24.275000000
# 4  2016-01-05 01:06:59.546000000
# 5  2016-01-20 19:54:46.166000000
# 8  2016-01-19 15:24:31.060000000

# %% [markdown]
# The dataframe df and the early_finishers share index values, so I really just
# want everything in the df which is not in early_finishers.

# %%
late_finishers=df[~df.index.isin(early_finishers.index)]
late_finishers.head()
# Out:
#                              student_id  assignment1_grade  \
# 2  D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3  FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 6  3217BE3F-E4B0-C3B6-9F64-462456819CE4          87.498744
# 7  F1CB5AA1-B3DE-5460-FAFF-BE951FD38B5F          80.576090
# 9  E2C617C2-4654-622C-AB50-1550C4BE42A0          59.270882
#
#           assignment1_submission  assignment2_grade  \
# 2  2016-01-09 05:36:02.389000000          85.512541
# 3  2016-04-30 06:50:39.801000000          68.824532
# 6  2016-03-05 11:05:25.408000000          69.998995
# 7  2016-01-24 18:24:25.619000000          72.518481
# 9  2016-03-06 12:06:26.185000000          59.270882
#
#           assignment2_submission  assignment3_grade  \
# 2  2016-01-09 06:39:44.416000000          68.410033
# 3  2016-04-30 17:20:38.727000000          61.942079
# 6  2016-03-09 07:29:52.405000000          55.999196
# 7  2016-01-27 13:37:12.943000000          65.266633
# 9  2016-03-13 02:07:25.289000000          53.343794
#
#           assignment3_submission  assignment4_grade  \
# 2  2016-01-15 20:22:45.882000000          54.728026
# 3  2016-05-12 07:47:16.326000000          49.553663
# 6  2016-03-16 22:31:24.316000000          50.399276
# 7  2016-01-30 14:34:36.581000000          65.266633
# 9  2016-03-17 07:30:09.241000000          53.343794
#
#           assignment4_submission  assignment5_grade  \
# 2  2016-01-11 12:41:50.749000000          49.255224
# 3  2016-05-07 16:09:20.485000000          49.553663
# 6  2016-03-18 07:19:26.032000000          45.359349
# 7  2016-02-03 22:08:49.002000000          65.266633
# 9  2016-03-20 21:45:56.229000000          42.675035
#
#           assignment5_submission  assignment6_grade  \
# 2  2016-01-11 17:31:12.489000000          44.329701
# 3  2016-05-24 12:51:18.016000000          44.598297
# 6  2016-03-19 10:35:41.869000000          45.359349
# 7  2016-02-16 14:22:23.664000000          65.266633
# 9  2016-03-27 15:55:04.414000000          38.407532
#
#           assignment6_submission
# 2  2016-01-17 16:24:42.765000000
# 3  2016-05-26 08:09:12.058000000
# 6  2016-03-23 14:02:00.987000000
# 7  2016-02-18 08:35:04.796000000
# 9  2016-03-30 20:33:13.554000000

# %% [markdown]
# #### Note(Others methods to find late_finishers):
# There are lots of other ways to do this. For instance, you could just copy and paste the first projection
# and change the sign from less than to greater than or equal to. This is ok, but if you decide you want to
# change the date down the road you have to remember to change it in two places. You could also do a join of
# the dataframe df with early_finishers - if you do a left join you only keep the items in the left dataframe,
# so this would have been a good answer. You also could have written a function that determines if someone is
# early or late, and then called .apply() on the dataframe and added a new column to the dataframe. This is a
# pretty reasonable answer as well.

# %% [markdown]
# ### Comparing means:
# As you've seen, the pandas data frame object has a variety of statistical functions associated with it. If
# we call the mean function directly on the data frame, we see that each of the means for the assignments are
# calculated. Let's compare the means for our two populations

# %%
print(early_finishers['assignment1_grade'].mean())
print(late_finishers['assignment1_grade'].mean())
# Out:
# 74.94728457024303
# 74.0450648477065

# %% [markdown]
# ### t-test:
# Ok, these look pretty similar. But, are they the same? What do we mean by similar? This is where the
# students' t-test comes in. It allows us to form the alternative hypothesis ("These are different") as well
# as the null hypothesis ("These are the same") and then test that null hypothesis.
# #### significance level as threshold(alpha):
# When doing hypothesis testing, we have to choose a significance level as a threshold for how much of a
# chance we're willing to accept. This significance level is typically called alpha. #For this example, let's
# use a threshold of 0.05 for our alpha or 5%. Now this is a commonly used number but it's really quite
# arbitrary.
# ### ttest_ind():
# The SciPy library contains a number of different statistical tests and forms a basis for hypothesis testing
# in Python and we're going to use the ttest_ind() function which does an independent t-test (meaning the
# populations are not related to one another).
# #### result:
# The result of ttest_index() are the t-statistic and a p-value.
# It's this latter value, the probability, which is most important to us, as it indicates the chance (between
# 0 and 1) of our null hypothesis being True.
#
# Let's bring in our ttest_ind function

# %%
from scipy.stats import ttest_ind

# %% [markdown]
# Let's run this function with our two populations, looking at the assignment 1 grades

# %%
ttest_ind(early_finishers['assignment1_grade'], late_finishers['assignment1_grade'])
# Out:
# Ttest_indResult(statistic=1.322354085372139, pvalue=0.1861810110171455)

# %% [markdown]
# #### conclusion:
# So here we see that the probability is 0.18, and this is above our alpha value of 0.05. This means that we
# cannot reject the null hypothesis. The null hypothesis was that the two populations are the same, and we
# don't have enough certainty in our evidence (because it is greater than alpha) to come to a conclusion to
# the contrary. This doesn't mean that we have proven the populations are the same.

# %% [markdown]
# Why don't we check the other assignment grades?

# %%
print(ttest_ind(early_finishers['assignment2_grade'], late_finishers['assignment2_grade']))
print(ttest_ind(early_finishers['assignment3_grade'], late_finishers['assignment3_grade']))
print(ttest_ind(early_finishers['assignment4_grade'], late_finishers['assignment4_grade']))
print(ttest_ind(early_finishers['assignment5_grade'], late_finishers['assignment5_grade']))
print(ttest_ind(early_finishers['assignment6_grade'], late_finishers['assignment6_grade']))
# Out:
# Ttest_indResult(statistic=1.2514717608216366, pvalue=0.2108889627004424)
# Ttest_indResult(statistic=1.6133726558705392, pvalue=0.10679998102227865)
# Ttest_indResult(statistic=0.049671157386456125, pvalue=0.960388729789337)
# Ttest_indResult(statistic=-0.05279315545404755, pvalue=0.9579012739746492)
# Ttest_indResult(statistic=-0.11609743352612056, pvalue=0.9075854011989656)

# %% [markdown]
# Ok, so it looks like in this data we do not have enough evidence to suggest the populations differ with
# respect to grade. Let's take a look at those p-values for a moment though, because they are saying things
# that can inform experimental design down the road. For instance, one of the assignments, assignment 3, has a
# p-value around 0.1. This means that if we accepted a level of chance similarity of 11% this would have been
# considered statistically significant. As a research, this would suggest to me that there is something here
# worth considering following up on. For instance, if we had a small number of participants (we don't) or if
# there was something unique about this assignment as it relates to our experiment (whatever it was) then
# there may be followup experiments we could run.

# %% [markdown]
# ### Statistically significant just by chance:
# P-values have come under fire recently for being insuficient for telling us enough about the interactions
# which are happening, and two other techniques, confidence intervalues and bayesian analyses, are being used
# more regularly. One issue with p-values is that as you run more tests you are likely to get a value which
# is statistically significant just by chance.
#
# Lets see a simulation of this. First, lets create a data frame of 100 columns, each with 100 numbers.

# %%
df1=pd.DataFrame([np.random.random(100) for x in range(100)])
df1.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.075224  0.836565  0.113267  0.059999  0.600650  0.074294  0.094037
# 1  0.289394  0.315348  0.290387  0.476673  0.637864  0.485760  0.072207
# 2  0.113846  0.920463  0.456652  0.263887  0.533282  0.560045  0.216898
# 3  0.486553  0.163997  0.086060  0.692870  0.972630  0.948474  0.323902
# 4  0.145305  0.271823  0.192672  0.458526  0.600061  0.744774  0.454836
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.237696  0.874268  0.592687  ...  0.407319  0.046112  0.712546  0.751383
# 1  0.094428  0.462867  0.853484  ...  0.072792  0.015788  0.734060  0.617322
# 2  0.170165  0.380149  0.081746  ...  0.506967  0.632136  0.788332  0.711987
# 3  0.529774  0.634412  0.141046  ...  0.173744  0.786708  0.616676  0.254469
# 4  0.079656  0.858284  0.661263  ...  0.343004  0.914221  0.555831  0.316075
#
#          94        95        96        97        98        99
# 0  0.787997  0.210883  0.008401  0.547768  0.358111  0.705878
# 1  0.543542  0.500344  0.932937  0.996134  0.340557  0.943894
# 2  0.557731  0.529557  0.953004  0.068897  0.248416  0.843848
# 3  0.624604  0.535349  0.694943  0.249446  0.621804  0.394673
# 4  0.156663  0.530481  0.247858  0.342327  0.238470  0.618088
#
# [5 rows x 100 columns]

# %% [markdown]
# do you understand the list comprehension and how I created this DataFrame? You
# don't have to use a list comprehension to do this, but you should be able to read this and figure out how it
# works as this is a commonly used approach on web forums.

# %% [markdown]
# Ok, let's create a second dataframe

# %%
df2=pd.DataFrame([np.random.random(100) for x in range(100)])

# %% [markdown]
# Are these two DataFrames the same? Maybe a better question is, for a given row inside of df1, is it the same
# as the row inside df2?
#
# Let's take a look. Let's say our critical value is 0.1, or and alpha of 10%. And we're going to compare each
# column in df1 to the same numbered column in df2. And we'll report when the p-value isn't less than 10%,
# which means that we have sufficient evidence to say that the columns are different.

# %% [markdown]
# Let's write this in a function called test_columns

# %%
def test_columns(alpha=0.1):
    # I want to keep track of how many differ
    num_diff=0
    # And now we can just iterate over the columns
    for col in df1.columns:
        # we can run out ttest_ind between the two dataframes
        teststat,pval=ttest_ind(df1[col],df2[col])
        # and we check the pvalue versus the alpha
        if pval<=alpha:
            # And now we'll just print out if they are different and increment the num_diff
            print("Col {} is statistically significantly different at alpha={}, pval={}".format(col,alpha,pval))
            num_diff=num_diff+1
    # and let's print out some summary stats
    print("Total number different was {}, which is {}%".format(num_diff,float(num_diff)/len(df1.columns)*100))

# %% [markdown]
# And now lets actually run this

# %%
test_columns()
# Out:
# Col 1 is statistically significantly different at alpha=0.1, pval=0.008443271679724312
# Col 6 is statistically significantly different at alpha=0.1, pval=0.027210561756536966
# Col 12 is statistically significantly different at alpha=0.1, pval=0.042854144158984274
# Col 47 is statistically significantly different at alpha=0.1, pval=0.0058690096822958115
# Col 51 is statistically significantly different at alpha=0.1, pval=0.05077376511845595
# Col 53 is statistically significantly different at alpha=0.1, pval=0.03211148853364875
# Col 57 is statistically significantly different at alpha=0.1, pval=0.03959056906389285
# Col 69 is statistically significantly different at alpha=0.1, pval=0.01318087091572181
# Col 79 is statistically significantly different at alpha=0.1, pval=0.05364685057614536
# Total number different was 9, which is 9.0%

# %% [markdown]
# Interesting, so we see that there are a bunch of columns that are different! In fact, that number looks a
# lot like the alpha value we chose. So what's going on - shouldn't all of the columns be the same? Remember
# that all the ttest does is check if two sets are similar given some level of confidence, in our case, 10%.
# The more random comparisons you do, the more will just happen to be the same by chance. In this example, we
# checked 100 columns, so we would expect there to be roughly 10 of them if our alpha was 0.1.
#
# We can test some other alpha values as well

# %%
test_columns(0.05)
# Out:
# Col 1 is statistically significantly different at alpha=0.05, pval=0.008443271679724312
# Col 6 is statistically significantly different at alpha=0.05, pval=0.027210561756536966
# Col 12 is statistically significantly different at alpha=0.05, pval=0.042854144158984274
# Col 47 is statistically significantly different at alpha=0.05, pval=0.0058690096822958115
# Col 53 is statistically significantly different at alpha=0.05, pval=0.03211148853364875
# Col 57 is statistically significantly different at alpha=0.05, pval=0.03959056906389285
# Col 69 is statistically significantly different at alpha=0.05, pval=0.01318087091572181
# Total number different was 7, which is 7.000000000000001%

# %% [markdown]
# So, keep this in mind when you are doing statistical tests like the t-test which has a p-value. Understand
# that this p-value isn't magic, that it's a threshold for you when reporting results and trying to answer
# your hypothesis. What's a reasonable threshold? Depends on your question, and you need to engage domain
# experts to better understand what they would consider significant.
#
# Just for fun, lets recreate that second dataframe using a non-normal distribution, I'll arbitrarily chose
# chi squared

# %%
df2=pd.DataFrame([np.random.chisquare(df=1,size=100) for x in range(100)])
test_columns()
# Out:
# Col 0 is statistically significantly different at alpha=0.1, pval=0.00038686538075632763
# Col 1 is statistically significantly different at alpha=0.1, pval=6.349434806572785e-05
# Col 2 is statistically significantly different at alpha=0.1, pval=0.0006867907275675793
# Col 3 is statistically significantly different at alpha=0.1, pval=0.0030320774498350505
# Col 4 is statistically significantly different at alpha=0.1, pval=1.2157796244488203e-05
# Col 5 is statistically significantly different at alpha=0.1, pval=0.00032775079220369346
# Col 6 is statistically significantly different at alpha=0.1, pval=0.0004228698130213537
# Col 7 is statistically significantly different at alpha=0.1, pval=1.0351400073626339e-05
# Col 8 is statistically significantly different at alpha=0.1, pval=0.010634472231933447
# Col 9 is statistically significantly different at alpha=0.1, pval=0.004687917474387682
# Col 10 is statistically significantly different at alpha=0.1, pval=0.001173028991488451
# Col 11 is statistically significantly different at alpha=0.1, pval=0.053762485867805326
# Col 12 is statistically significantly different at alpha=0.1, pval=0.0008793067983123588
# Col 13 is statistically significantly different at alpha=0.1, pval=0.00013306833651435365
# Col 14 is statistically significantly different at alpha=0.1, pval=0.003980147486147961
# Col 15 is statistically significantly different at alpha=0.1, pval=0.0007493086433630047
# Col 16 is statistically significantly different at alpha=0.1, pval=0.001276856038822832
# Col 17 is statistically significantly different at alpha=0.1, pval=6.496285579843558e-07
# Col 18 is statistically significantly different at alpha=0.1, pval=0.0030996590824182942
# Col 19 is statistically significantly different at alpha=0.1, pval=3.334132999625662e-06
# Col 20 is statistically significantly different at alpha=0.1, pval=8.074603355150222e-05
# Col 21 is statistically significantly different at alpha=0.1, pval=0.0011791521541660098
# Col 22 is statistically significantly different at alpha=0.1, pval=5.0973443219022764e-05
# Col 23 is statistically significantly different at alpha=0.1, pval=4.0727514482984594e-05
# Col 24 is statistically significantly different at alpha=0.1, pval=4.178833952107138e-05
# Col 25 is statistically significantly different at alpha=0.1, pval=0.0003848519589188521
# Col 26 is statistically significantly different at alpha=0.1, pval=0.000559310202592072
# Col 27 is statistically significantly different at alpha=0.1, pval=0.015784466716053512
# Col 28 is statistically significantly different at alpha=0.1, pval=0.00018742465523754513
# Col 29 is statistically significantly different at alpha=0.1, pval=0.028242845467197637
# Col 30 is statistically significantly different at alpha=0.1, pval=0.0011178903821811251
# Col 31 is statistically significantly different at alpha=0.1, pval=4.747713266494576e-05
# Col 32 is statistically significantly different at alpha=0.1, pval=0.005246793247692232
# Col 33 is statistically significantly different at alpha=0.1, pval=0.019865541539317393
# Col 34 is statistically significantly different at alpha=0.1, pval=1.5182118459923372e-05
# Col 35 is statistically significantly different at alpha=0.1, pval=0.0020868013865555073
# Col 36 is statistically significantly different at alpha=0.1, pval=0.009691688036149164
# Col 37 is statistically significantly different at alpha=0.1, pval=0.0006864312213009601
# Col 38 is statistically significantly different at alpha=0.1, pval=0.0002007707390711448
# Col 39 is statistically significantly different at alpha=0.1, pval=4.584599661659787e-05
# Col 40 is statistically significantly different at alpha=0.1, pval=9.081414092133171e-05
# Col 41 is statistically significantly different at alpha=0.1, pval=0.0007741341646511051
# Col 42 is statistically significantly different at alpha=0.1, pval=0.00013594436719396443
# Col 43 is statistically significantly different at alpha=0.1, pval=3.084449357503816e-05
# Col 44 is statistically significantly different at alpha=0.1, pval=0.002187502315144267
# Col 45 is statistically significantly different at alpha=0.1, pval=0.044487056379880346
# Col 46 is statistically significantly different at alpha=0.1, pval=0.005137233884043776
# Col 47 is statistically significantly different at alpha=0.1, pval=1.419660613863868e-05
# Col 48 is statistically significantly different at alpha=0.1, pval=9.694737945700606e-05
# Col 49 is statistically significantly different at alpha=0.1, pval=0.0006166087605906662
# Col 50 is statistically significantly different at alpha=0.1, pval=0.0017981694498952845
# Col 51 is statistically significantly different at alpha=0.1, pval=0.008337646546680842
# Col 52 is statistically significantly different at alpha=0.1, pval=0.0014354321494041444
# Col 54 is statistically significantly different at alpha=0.1, pval=0.002862377304629379
# Col 55 is statistically significantly different at alpha=0.1, pval=0.0010114665067267005
# Col 56 is statistically significantly different at alpha=0.1, pval=0.0006879647199799714
# Col 57 is statistically significantly different at alpha=0.1, pval=0.0014327815991094855
# Col 58 is statistically significantly different at alpha=0.1, pval=0.001094755567989092
# Col 59 is statistically significantly different at alpha=0.1, pval=0.00012693766206711154
# Col 60 is statistically significantly different at alpha=0.1, pval=0.0009951759847164688
# Col 61 is statistically significantly different at alpha=0.1, pval=8.902053306012103e-06
# Col 62 is statistically significantly different at alpha=0.1, pval=0.0008351968935562674
# Col 63 is statistically significantly different at alpha=0.1, pval=0.00022187853144815315
# Col 64 is statistically significantly different at alpha=0.1, pval=0.0007243661671067423
# Col 65 is statistically significantly different at alpha=0.1, pval=0.0012114331708560416
# Col 66 is statistically significantly different at alpha=0.1, pval=0.00035224187704615287
# Col 67 is statistically significantly different at alpha=0.1, pval=0.0012447710674574975
# Col 68 is statistically significantly different at alpha=0.1, pval=0.00037382378757314604
# Col 69 is statistically significantly different at alpha=0.1, pval=0.0009141825765720875
# Col 70 is statistically significantly different at alpha=0.1, pval=0.0010675946114914515
# Col 71 is statistically significantly different at alpha=0.1, pval=0.00047955222882884157
# Col 72 is statistically significantly different at alpha=0.1, pval=0.010897198448284405
# Col 73 is statistically significantly different at alpha=0.1, pval=0.03079335065164523
# Col 74 is statistically significantly different at alpha=0.1, pval=1.2481975982258022e-05
# Col 75 is statistically significantly different at alpha=0.1, pval=0.0019665478035255824
# Col 76 is statistically significantly different at alpha=0.1, pval=0.003966431039733352
# Col 77 is statistically significantly different at alpha=0.1, pval=0.0007599424572271536
# Col 78 is statistically significantly different at alpha=0.1, pval=0.06306936214998683
# Col 79 is statistically significantly different at alpha=0.1, pval=0.0020921481757683975
# Col 80 is statistically significantly different at alpha=0.1, pval=5.81287879711204e-06
# Col 81 is statistically significantly different at alpha=0.1, pval=0.00021975505059151974
# Col 82 is statistically significantly different at alpha=0.1, pval=0.0037338037757471887
# Col 83 is statistically significantly different at alpha=0.1, pval=0.012952366711779809
# Col 84 is statistically significantly different at alpha=0.1, pval=0.000967273664407259
# Col 85 is statistically significantly different at alpha=0.1, pval=5.553188964732347e-05
# Col 86 is statistically significantly different at alpha=0.1, pval=0.0001618071704123644
# Col 87 is statistically significantly different at alpha=0.1, pval=0.0044976713381353
# Col 88 is statistically significantly different at alpha=0.1, pval=0.0001125687682233186
# Col 89 is statistically significantly different at alpha=0.1, pval=1.4862810434871532e-06
# Col 90 is statistically significantly different at alpha=0.1, pval=0.0004162257499129749
# Col 91 is statistically significantly different at alpha=0.1, pval=0.0009749992178170676
# Col 92 is statistically significantly different at alpha=0.1, pval=0.010468168564192078
# Col 93 is statistically significantly different at alpha=0.1, pval=0.0002542624536831672
# Col 94 is statistically significantly different at alpha=0.1, pval=6.604910943644063e-05
# Col 95 is statistically significantly different at alpha=0.1, pval=0.017538956301837442
# Col 96 is statistically significantly different at alpha=0.1, pval=0.00034126773935504444
# Col 97 is statistically significantly different at alpha=0.1, pval=0.009006407038760685
# Col 98 is statistically significantly different at alpha=0.1, pval=0.004437667379633357
# Col 99 is statistically significantly different at alpha=0.1, pval=0.0007487492137165387
# Total number different was 99, which is 99.0%

# %% [markdown]
# Now we see that all or most columns test to be statistically significant at the 10% level.

# %% [markdown]
# In this lecture, we've discussed just some of the basics of hypothesis testing in Python. I introduced you to the SciPy library, which you can use for the students t test. We've discussed some of the practical issues which arise from looking for statistical significance. There's much more to learn about hypothesis testing, for instance, there are different tests used, depending on the shape of your data and different ways to report results instead of just p-values such as confidence intervals or bayesian analyses. But this should give you a basic idea of where to start when comparing two populations for differences, which is a common task for data scientists.
